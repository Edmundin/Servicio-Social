# %%
# !pip install yfinance

# %%
# !pip install ruamel.yaml

# %%
import yfinance as yf 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import date, timedelta
import time

# %%
DWJ = yf.Ticker("^DJI") #Con esta paquetería podemos extraer distintos datos a partir de sus etiquetas
print(DWJ.info)
# Out:
# {'exchange': 'DJI', 'shortName': 'Dow Jones Industrial Average', 'exchangeTimezoneName': 'America/New_York', 'exchangeTimezoneShortName': 'EDT', 'isEsgPopulated': False, 'gmtOffSetMilliseconds': '-14400000', 'quoteType': 'INDEX', 'symbol': '^DJI', 'messageBoardId': 'finmb_INDEXDJI', 'market': 'us_market', 'previousClose': 34061.06, 'regularMarketOpen': 33854.17, 'twoHundredDayAverage': 34958.176, 'trailingAnnualDividendYield': None, 'payoutRatio': None, 'volume24Hr': None, 'regularMarketDayHigh': 33854.17, 'navPrice': None, 'averageDailyVolume10Day': 425666000, 'totalAssets': None, 'regularMarketPreviousClose': 34061.06, 'fiftyDayAverage': 34068.168, 'trailingAnnualDividendRate': None, 'open': 33854.17, 'toCurrency': None, 'averageVolume10days': 425666000, 'expireDate': None, 'yield': None, 'algorithm': None, 'dividendRate': None, 'exDividendDate': None, 'beta': None, 'circulatingSupply': None, 'startDate': None, 'regularMarketDayLow': 32685.1, 'priceHint': 2, 'currency': 'USD', 'reg
# ...

# %%
print(DWJ.info.keys())
# Out:
# dict_keys(['exchange', 'shortName', 'exchangeTimezoneName', 'exchangeTimezoneShortName', 'isEsgPopulated', 'gmtOffSetMilliseconds', 'quoteType', 'symbol', 'messageBoardId', 'market', 'previousClose', 'regularMarketOpen', 'twoHundredDayAverage', 'trailingAnnualDividendYield', 'payoutRatio', 'volume24Hr', 'regularMarketDayHigh', 'navPrice', 'averageDailyVolume10Day', 'totalAssets', 'regularMarketPreviousClose', 'fiftyDayAverage', 'trailingAnnualDividendRate', 'open', 'toCurrency', 'averageVolume10days', 'expireDate', 'yield', 'algorithm', 'dividendRate', 'exDividendDate', 'beta', 'circulatingSupply', 'startDate', 'regularMarketDayLow', 'priceHint', 'currency', 'regularMarketVolume', 'lastMarket', 'maxSupply', 'openInterest', 'marketCap', 'volumeAllCurrencies', 'strikePrice', 'averageVolume', 'priceToSalesTrailing12Months', 'dayLow', 'ask', 'ytdReturn', 'askSize', 'volume', 'fiftyTwoWeekHigh', 'forwardPE', 'maxAge', 'fromCurrency', 'fiveYearAvgDividendYield', 'fiftyTwoWeekLow', 'bid', '
# ...

# %%
# 1) Exchange
print(DWJ.info['exchange']) 

# 2) Open
print(DWJ.info['open'])
# Out:
# DJI
# 33425.96

# %%
import datetime

start = datetime.datetime(2019,5,31) 
end = datetime.datetime(2022,4,28) 

 
print(DWJ.history(start=start, end=end))
# Out:
#                     Open          High           Low         Close     Volume  \
# Date
# 2019-05-31  25046.310547  25046.310547  24809.509766  24815.039062  292230000
# 2019-06-03  24830.160156  24935.210938  24680.570312  24819.779297  328240000
# 2019-06-04  24962.820312  25343.769531  24962.820312  25332.179688  281690000
# 2019-06-05  25451.000000  25544.660156  25373.580078  25539.570312  262660000
# 2019-06-06  25567.449219  25800.300781  25518.050781  25720.660156  248070000
# 2019-06-07  25768.720703  26072.750000  25768.720703  25983.939453  263010000
# 2019-06-10  26090.220703  26210.609375  26054.310547  26062.679688  249280000
# 2019-06-11  26180.589844  26248.669922  25998.869141  26048.509766  253490000
# 2019-06-12  26040.300781  26082.099609  25958.660156  26004.830078  223690000
# 2019-06-13  26036.939453  26146.910156  25995.710938  26106.769531  213400000
# 2019-06-14  26076.359375  26162.279297  25988.089844  26089.609375  208020000
# ...

# %%
DWJ.history(period="max")
# Out:
#                     Open          High           Low         Close     Volume  \
# Date
#
# Out:
#                                    Open          High           Low  \
# Datetime
# 2022-05-05 09:30:00-04:00  33854.171875  33854.171875  33757.750000
# 2022-05-05 09:31:00-04:00  33772.789062  33786.511719  33734.789062
# 2022-05-05 09:32:00-04:00  33743.609375  33756.128906  33731.160156
# 2022-05-05 09:33:00-04:00  33727.089844  33771.539062  33717.589844
# 2022-05-05 09:34:00-04:00  33769.769531  33775.929688  33749.660156
# 2022-05-05 09:35:00-04:00  33758.910156  33799.328125  33758.910156
# 2022-05-05 09:36:00-04:00  33777.511719  33780.929688  33760.898438
# 2022-05-05 09:37:00-04:00  33773.171875  33784.320312  33735.089844
# 2022-05-05 09:38:00-04:00  33742.980469  33772.609375  33738.261719
# 2022-05-05 09:39:00-04:00  33746.878906  33760.761719  33741.710938
# 2022-05-05 09:40:00-04:00  33734.769531  33775.820312  33734.769531
# 2022-05-05 09:41:00-04:00  33763.828125  33819.929688  33762.191406
# 2022-05-05 09:42:00-04:00  33788.789062  33789.988281  33753.851562
# ...

# %%
date.today() - timedelta(days=7)
# Out:
# datetime.date(2022, 4, 29)

# %%
type(DWJ_hist)
# Out:
# pandas.core.frame.DataFrame

# %%
DWJ_hist.describe()
# Out:
#                Open          High           Low         Close        Volume  \
# count   1949.000000   1949.000000   1949.000000   1949.000000  1.949000e+03
# mean   33171.360206  33185.293229  33157.364146  33171.222030  9.317563e+05
# std      294.006969    293.465984    294.749452    293.939338  7.269569e+05
# min    32453.029297  32478.880859  32449.869141  32451.599609  0.000000e+00
# 25%    32993.089844  33014.730469  32978.109375  32993.578125  5.703310e+05
# 50%    33155.160156  33167.261719  33142.500000  33155.281250  7.538430e+05
# 75%    33292.878906  33306.328125  33280.988281  33293.089844  1.065080e+06
# max    34109.898438  34117.738281  34083.929688  34112.699219  1.295279e+07
#
#        Dividends  Stock Splits
# count     1949.0        1949.0
# mean         0.0           0.0
# std          0.0           0.0
# min          0.0           0.0
# 25%          0.0           0.0
# 50%          0.0           0.0
# 75%          0.0           0.0
# ...

# %%
DWJ_hist["Open"]
# Out:
# Datetime
# 2022-04-29 09:30:00-04:00    33787.011719
# 2022-04-29 09:31:00-04:00    33779.500000
# 2022-04-29 09:32:00-04:00    33755.710938
# 2022-04-29 09:33:00-04:00    33838.839844
# 2022-04-29 09:34:00-04:00    33815.320312
# 2022-04-29 09:35:00-04:00    33775.531250
# 2022-04-29 09:36:00-04:00    33786.171875
# 2022-04-29 09:37:00-04:00    33767.570312
# 2022-04-29 09:38:00-04:00    33767.589844
# 2022-04-29 09:39:00-04:00    33789.730469
# 2022-04-29 09:40:00-04:00    33790.558594
# 2022-04-29 09:41:00-04:00    33801.750000
# 2022-04-29 09:42:00-04:00    33807.949219
# 2022-04-29 09:43:00-04:00    33796.550781
# 2022-04-29 09:44:00-04:00    33760.410156
# 2022-04-29 09:45:00-04:00    33724.261719
# 2022-04-29 09:46:00-04:00    33777.429688
# 2022-04-29 09:47:00-04:00    33766.218750
# 2022-04-29 09:48:00-04:00    33763.039062
# 2022-04-29 09:49:00-04:00    33772.851562
# 2022-04-29 09:50:00-04:00    33777.410156
# 2022-04-29 09:51:00-04:00    33788.839844
# ...

# %%
import seaborn as sbn
sbn.set(rc={'figure.figsize':(25, 15)})
DWJ_hist['Open'].plot(marker='o',linestyle='-')

# %%
Nasdaq_hist = Nasdaq.history(start=(date.today() - timedelta(days = 1)) , end= date.today(), interval="1m")

# %%
IPC_hist = IPC.history(start=datetime.date(2022, 5, 9), end=datetime.date(2022, 5, 9) + timedelta(days=1), interval="1m")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-75bd96550321> in <module>
# ----> 1 IPC_hist = DWJ.history(start=datetime.date(2022, 5, 9), end=datetime.date(2022, 5, 9) + timedelta(days=1), interval="1m")
#
# NameError: name 'DWJ' is not defined
